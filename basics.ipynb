# %%
8178
# Out:
# 8178

# %%
a= 23
b =3.111
c = "hello"
d =True
e = None

# %%
fruits = ["apple" , "banana" , "cherry"]
coords = (3, 3, 2)
items = {12, 5, 2, 12, 13}
person = {"name":"John" , "age": 36, "country": "Norway"}

# %%
a = [2,5,6,12,11,21,22,51]

# %%
11 in a
# Out:
# True
